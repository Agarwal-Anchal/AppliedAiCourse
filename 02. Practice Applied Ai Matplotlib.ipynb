# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2,4,6,8])

# %%
plt.xlabel("Numbers")
# Out:
# Text(0.5, 0, 'Numbers')

# %%
plt.ylabel("Indices")
# Out:
# Text(0, 0.5, 'Indices')

# %%
plt.title("MyPlot")
# Out:
# Text(0.5, 1.0, 'MyPlot')

# %%
plt.plot([1,2,3,4,5],[2,4,6,8,10],'ro')

# %%
plt.plot([1,2,3,4,5],[2,4,6,8,10],'ro',label='abc')
plt.plot([2,4,5,6,7,4],'b--',linewidth=2,label='def')
plt.legend()

# %%
x1=[1,2,3,4]
y1=[2,4,6,8]
x2=[2,4,6,8]
y2=[1,4,8,16]

lines=plt.plot(x1,y1,x2,y2)
plt.setp(lines[0],color='r')
# Out:
# [None]

# %%
x1=[1,2,3,4]
y1=[2,4,6,8]
x2=[2,4,6,8]
y2=[1,4,8,16]

plt.figure()

plt.subplot(211)
plt.plot(x1,y1)
plt.subplot(212)
plt.plot(x2,y2)
plt.show()
