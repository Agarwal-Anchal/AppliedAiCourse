# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('iris.csv')

# %%
print(iris.ndim)
print(iris.shape)
# Out:
# 2
# (150, 5)

# %%
print(iris.size)
# Out:
# 750

# %%
print(iris.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
iris['target'].value_counts()
# Out:
# 2.0    50
# 1.0    50
# 0.0    50
# Name: target, dtype: int64

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris,hue='target',size=4) \
    .map(plt.scatter,'sepal length (cm)','sepal width (cm)') \
     .add_legend();
# Out:
# C:\Users\anchal\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#3d plots use plotly

# %%
#Pair plots

# %%
plt.close()

# %%
sns.set_style("whitegrid")

# %%
sns.pairplot(iris,hue='target',height=2)
plt.show()

# %%
#can simply separate by looking at the plot using if else bw
#petal length and petal width (target 0 is well separated)

# %%
#pair plots difficult when high dimensional data till 6 is fine
